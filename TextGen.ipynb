# %% [markdown]
# # Black boxing LSTM
# In this worksheet LSTM is approached from a black box perspective. Although the workings of LSTM are not overly complicated, see for example the explanation of Chris Olah at http://colah.github.io/posts/2015-08-Understanding-LSTMs/, in practice it is not easy to find out what the relationship between the model and the data is. This in contrast to convolutional networks, that allow an intuition to be formed. Still some pragmatic model and data relationships can be established; this worksheet focusses on how input and output data can be shaped.
#
# # High level conceptual model of an LSTM
# An LSTM can be seen as a model that models discrete state transitions. The data parts consist of:
#
# - Input data per discrete state
# - Output data per discrate state
# - Internal state built up during previous steps
#
# The input data is merged with the internal state to predict the output data. At each state transition the internal state of the LSTM is updated, and past to the next state. The discrete state transitions are usually fed as event or timeseries into an LSTM.
#
# Using the blackbox model, the trick is to find out how the state is built up in an LSTM, and what predictions should be made.
#
# # Shaping the input and output data
# The example in this worksheet focusses on a single timeseries. The insights generated using this example should generalize to the case of multiple timeseries. The example is text generation. Based on a training text a LSTM will be estimated. Using a seed text subsequently characters will be generated which might contain more of Nietzsches wisdom, total gibberish, or something in between.
#
# A LSTM allows for the shaping of both the input and the output data. A first observation: a timeseries, or text in this case, can be fed into an LSTM as a single instance, or it can be cut into (more or less independent) pieces. In the last case the LSTM will more or less be seen as handling multiple observations, but there are subtleties. A second observation: the output can be constrained to a single output per observation, or an output per observation within the timeseries. Lastly, if cutting a single instance into multiple pieces, the internal state in the LSTM can be transfered between the pieces or not.
#
# To clarify, the above statements will be placed in the context of text generation by way of several examples.
#
# ## One timeseries, one output
# Somewhat silly, an entire text minus that last character could be fed into an LSTM to predict the last character. In this case there is a single timeseries and a single output. This setup is silly for two reasons:
#
# - The LSTM only learns to predict a single specific character.
# - The LSTM assumes that the complete text is a valid context for that character.
#
# Technically it would work, but conceptually it would be nonsense. Predicting positive or negative sentiment in the IMDB dataset could be a valid application of this setup, but then there would be more than one time series.
#
# ## One timeseries, multiple outputs
# Changing the setup, one could use the first character to predict the second, the first two to predict the third, and so on. This setup seems to be more sensible: a lot of different characters would be learned. This setup might work. The complexity of the entire text is taken as a single internal state though. Also, the output dimension becomes as long as the input.
#
# ## Cutting the timeseries, one output
# This setup is originally used in the example of fchollet. Take a text, chop it into pieces of 50 characters, and then predict the next characters. The pieces overlap in the sense that the first piece goes from 0-49, the second from 3-52, etc. This setup take away an objection to the previous example. The context for the prediction of a character is 50 characters; basically the sentence before it. This seems reasonable.
#
# In a more technical timeseries one might conjecture that there is actually a fixed set of mechanims underlying the timeseries. In this case one would not want to chop up the sequences. A somewhat in between option is covered in the next section.
#
# ## Cutting the timeseries, one output, statefull state
# No, that is not a typo in the title. In the last example the text was cut into more or less independent pieces. Conceptually this seems to be a reasonable fit. One could alter the example, by allowing state to flow between the pieces. In other words, at the start the internal state is random or empty. After training a piece, the state is propagated to the next piece. This setup puts back some of the earlier objections. Still, technically it is possible.
#
# The four examples about outlined some design considerations for LSTMS. The examples should give an intuition of the basic workings of an LSTM. Some of the examples seem reasonable, some silly, and some in between. Hence the black box. Apart from these considerations, there are ofcourse hyperparameters to consider.
#
# In this worksheet several examples will be illustrated. These illustrations show the coding involved in the different setups, and might create new insights into text prediction.
#
# The following examples are given:
# - Cutting the timeseries, one output
# - Cutting the timeseries, one output, statefull state (code changes only)
# - Cutting the timeseries, multiple outputs
#
#
# ## Code attribution
# The majority of the code below was written bij fchollet as part of the Keras project. The original code can be found here: https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.
#
# The code above is probably inspired by: http://karpathy.github.io/2015/05/21/rnn-effectiveness/

# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 970 (CNMeM is enabled with initial size: 25.0% of memory, cuDNN 5105)
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
path = get_file('nietzsche.txt', origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600901
# total chars: 59

# %% [markdown]
# # Code example: cutting the timeseries, one output
# This code consists of the original code of fchollet.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=128, nb_epoch=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        output = ""
        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            output += next_char
        print(output)
# Out:
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200287/200287 [==============================] - 60s - loss: 1.9889
#
# ----- diversity: 0.2
# ----- Generating with seed: "n should venture
# forward when the fear-i"
# n should venture
# forward when the fear-in the feeting and the fact higher the grates of the self man is the feetical of the self and the self more and moral of the self will one when the self the self will and the self will the self-must the serition, the fact the fact the fact and and the feetically the the feetion. the presention of the self moral the the self will an the serverical and and sumpled and in the an the self man in the se
#
# ----- diversity: 0.5
# ----- Generating with seed: "n should venture
# forward when the fear-i"
# n should venture
# forward when the fear-in the secrew by the feeting of a the personed by the the friminity mution of the deasor the came to the world it is uterionally symplesses to the soul, in the the prepertions, and it is man one who been an about the the feetical been the self herting religion of the hove the can be the something as to which the the seeks of the master it is religion for the great belough discomplesss and all even
#
# ----- diversity: 1.0
# ----- Generating with seed: "n should venture
# forward when the fear-i"
# n should venture
# forward when the fear-inually with sime rockions., the sage--ithervers of
# the feeling of batt, that the devadatters, be
# chrincts;
# achisposoly preserfience in poott, hering,"
# vatues ainineved or ctintt, new wish the dacitions forter the farts and can aid. when a pensentiou all perlaus be betram and who whece sees must the perturiis for gover, to the day breased to a truegness,
# hution and in the
# crevert), charch, remently
#
# ----- diversity: 1.2
# ----- Generating with seed: "n should venture
# forward when the fear-i"
# n should venture
# forward when the fear-ih;
# future as my an the expectedluses the beekf
# restasy curinens agnersetarian of oblarimy but oher one as
# a to mayn--entimes -problenle mattcousli-hi. suuths
# sodr abmold, that is good. humar itterfuncal betresely,
# a but
# butners, fremoluncely will ersolay this means, brels senialleelo instrain bfing", the fact s"bagation.
#
#
# 2v. and indo suidful tis owh,
# he has dofoeds not reaging ityeltted by selfl
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200287/200287 [==============================] - 60s - loss: 1.6662
#
# ----- diversity: 0.2
# ----- Generating with seed: "fe at all except upon the basis
# of persp"
# fe at all except upon the basis
# of perspises and more inderstand to the sense and the present to the present a morality and the such a such as the subject of the power to be all the subject of the subject of the morality of the present to the subject that it is a man is a such a such also the sense and any the subject of the present and the morality of the soul the such a such a consideration of the sense, and world to the sense, the wo
#
# ----- diversity: 0.5
# ----- Generating with seed: "fe at all except upon the basis
# of persp"
# fe at all except upon the basis
# of perspise the truth and consiments and such a such will to fable to be one many and be such in their the subject to the longer and for his longen who he has the reason of the inderstand to means of reason as the most careal of a feeling the searly and his part and loves the present and assent which in the seart and moral of the
# such man is many the one may have be sense--there is a litere to be any easi
#
# ----- diversity: 1.0
# ----- Generating with seed: "fe at all except upon the basis
# of persp"
# fe at all except upon the basis
# of perspits and eors an among much torushoch
# of at the
# bowedners
# spay bafometous moralitee". relog, this be   behove-be is cever lookfto nafusus--the aristeblition, in the not such awalls final what is granating by come that fa! reed, an whoke
#
# indent
# merenented and most mysils to face invinality and welld fre exorts have thet-exultured underst epgrendurakerian more wrongering re is indepoble in langisira
#
# ----- diversity: 1.2
# ----- Generating with seed: "fe at all except upon the basis
# of persp"
# fe at all except upon the basis
# of perspirieshrohy of
# a
# neholder les his eow
# an will beaouse, sa(trasting oo the world are
# freeoken nearcy, butather in one, many have about the. we has toe warts
# loughidads)ol in when indreabitnces, that so kind under thbit thate is suches if their itself in lightionsd--the betopthal,s! to su
# milits. nothing for unded (ee haw to has baea upin accordene thky, carcy of himself ta means of worning toauthing
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200287/200287 [==============================] - 61s - loss: 1.5500
#
# ----- diversity: 0.2
# ----- Generating with seed: "istian-moral explanation of immediate
# pe"
# istian-moral explanation of immediate
# personal the most sensible and the most sensible the same the same the sension of the same to the sentiments of the man is to the passion of the more to himself to him to the possibly to him to the happeration of the present to himself and the sensious of the thing of the sension of the the the world of the stronger of the possibly to the sentiments, and the the happens of the philosophy and the som
#
# ----- diversity: 0.5
# ----- Generating with seed: "istian-moral explanation of immediate
# pe"
# istian-moral explanation of immediate
# perforing to the experiences of the reflement of the spiritual of the domaintow of interpretation of the unermence of the problem to him and to the actional to the call to his renour the some as i the profound to the signist of the respect to himself. how and the sensious of a higher something of him, and attempt to him has not the more to the
# nowars, and philosophys and the are of the simply to hav
#
# ----- diversity: 1.0
# ----- Generating with seed: "istian-moral explanation of immediate
# pe"
# istian-moral explanation of immediate
# perous and which impores to hamm of metaphy and thus! and imperative of right no forgershcoss man woold indeed
# lys aw earwory, in order loves. the
# tand aest of simn
# inde filse
# ideame!
# physoch are time in philosiparives from power. lamgication which earthers ow emsty. of great mottain, the countor, cevtual cominially to women and people,
# indeed and foor thy senscation, that chysted to us it the recei
#
# ----- diversity: 1.2
# ----- Generating with seed: "istian-moral explanation of immediate
# pe"
# istian-moral explanation of immediate
# periossobulingal, seilnge, decetsum had nowlogy,". could heavy conliush to the
# communessss.h
# it, threver generat" nough
# ywould be form.m--a benony
# and therefore to himsly, which an attineso,, vail
# anverstly
# you forchen; and to the men blood and fature toness, animan thereby fund
# age
# psychars psy-ove pheposith, devimity the acr; us imponcaps for this has exceptiesty fircunal weres libvt to humany.
#
#
#
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200287/200287 [==============================] - 54s - loss: 1.5041
#
# ----- diversity: 0.2
# ----- Generating with seed: "ry soon the saint turns upon
# himself tha"
# ry soon the saint turns upon
# himself that the sense and the end all the experiminary and presenting the stand and the still and everything of the sense of the sense and the still of a port of the still sperions of the subsequent to the sense of the sense and all the sense of the stronger and the morality of the sense and the desire of the still and the moral and the still the sense of the still of a constining the self that the morality
#
# ----- diversity: 0.5
# ----- Generating with seed: "ry soon the saint turns upon
# himself tha"
# ry soon the saint turns upon
# himself that standand of all to of good and because for the fact in southes of the master for in the moral reasons which which we all this ense of the offering that the oppositions of fact that and the power with fear to such reality and individual to the morality in the reselved, and which could now feel of such all tensions as the morality with the last conception of many his "longer precisely the more con
#
# ----- diversity: 1.0
# ----- Generating with seed: "ry soon the saint turns upon
# himself tha"
# ry soon the saint turns upon
# himself that he was viratise. lift of
# nature- or sociedly sherity standards spail chiene of plaines, an explaned neanest the always in one
# tler way order but have apple". to
# they changed
# (new wighting-sincritical,
# a
# normites were loud all the undertains pleasure of designians, and
# rath one, moralst. connechetel. and wrong from every sturility, like as port ad unlegand these. the poastable of beloned seid to
#
# ----- diversity: 1.2
# ----- Generating with seed: "ry soon the saint turns upon
# himself tha"
# ry soon the saint turns upon
# himself than thewoof rebaly, an 1nows consequence of beatorigit of the owe
# sugeds gods a contlaft, than of will
# rather? but, in the verys one
# remeently and eltted, and in sympaild, thaten of them thoso such
# a dauber beming obveut gas to the
# most samne the very probled--that we away snew a
# social at it one iuncimate like discriesiots?
#
#        we firap less-toy one ty according so-magicn for itself war0fencthe
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200287/200287 [==============================] - 55s - loss: 1.4740
#
# ----- diversity: 0.2
# ----- Generating with seed: "d, such as have the ambition to
# conceal "
# d, such as have the ambition to
# conceal and strength, and and the problem and the sension of the strength of the subtimestic presses, and an an as the sensible the struegs of the some the strength, the sension of the world and the strength, and and the presses the sensible the world and the strongest and the strongest and the more and the subtimes of the subtimate the strength of the subtion of the superior of the subtion of the press a
#
# ----- diversity: 0.5
# ----- Generating with seed: "d, such as have the ambition to
# conceal "
# d, such as have the ambition to
# conceal of the best the more and the pressem, and everything despited the world, and the desermention of the same in the presstimes in the endurance and sense and chmplan, of the respectable the precisely to be or the last as the power, and the such man decessing the world and the other ask in the freedom no the mansire of the own sympathing and more of the such worth the happent, but it is the cause, whi
#
# ----- diversity: 1.0
# ----- Generating with seed: "d, such as have the ambition to
# conceal "
# d, such as have the ambition to
# conceal takems of more should with she the feeling wellous to be funted, to back, as i. the caintebly
# scaunty differences there around ald way of "to the philosophy the prelivers, a dearedes druticarebily religion of everstands now
# fear, ampress
# the longest the badness slaves and amouncetful complitely consequentlyts he fores religion mothers fasimular
# like that the most disposition viewwith the
# sacrifice
#
# ----- diversity: 1.2
# ----- Generating with seed: "d, such as have the ambition to
# conceal "
# d, such as have the ambition to
# conceal occabious to wommand--consend callebe, when reversic indeligion for sor so wrowe
# ranmew lastretated, of twat who aratted
# them: muchmeaning, founded
# the princts with a do arm poining grous dnin.
# butrospon, nature--man may action
# of the
# world the
# provaranted,
# and a philosophep which multrod, no   "
# . one undermanigan, of aniwagitadiss, -artides, in
# such communcires. he dreos, in
# fel wernem inmodepr
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200287/200287 [==============================] - 54s - loss: 1.4538
#
# ----- diversity: 0.2
# ----- Generating with seed: "has actually looked inside, and into the"
# has actually looked inside, and into the struggle of the consciousness of the sense of the stronger of the sense of the hearts to the stronger of the sense of the sacistic of the soul of the strange of the sense of the conditional and morality of the strange of the still the strange of the strange of the constitutes the stated to the constitutes the soul of the superstition of the soul of the soul of the strange of the states of the con
#
# ----- diversity: 0.5
# ----- Generating with seed: "has actually looked inside, and into the"
# has actually looked inside, and into the sense which not the has a worth one is not to could to the sense of the prasent, and and a grand were a thing--and for the plaising man and that is the soul, in the still and without his labard of the chalos: what is a precisely even not to them, which is to the religious philosophers and indistinction of the common in what is not the more and presomed inained the sensitive now modernal characted
#
# ----- diversity: 1.0
# ----- Generating with seed: "has actually looked inside, and into the"
# has actually looked inside, and into the
# knows grace to the disoning? propoleds bring ecover, and the conditional, case unmascetful mornk
# finar cultume. them, been i not, of gragterable in a called, counder to pra, to still my and in so thans live to fee whole does not, clader
# fan realson, an by their act of viutuality a sees individually and of supideds in the belong and human vartes, belong in
# the comprehensible, in evid undom of the
#
# ----- diversity: 1.2
# ----- Generating with seed: "has actually looked inside, and into the"
# has actually looked inside, and into the gant of to learn, that the amastome home" means." to ter would caparists; ppriltment.bully se3fulary has not in the way heared of the state are moderiment worth) it begin
# headiness
# ofness, be ferows forgected the own to time, the
# pashous one a2.
#
#
# afatorthor, seem iseled of mis
# nacuar power in borism
# and such nothing, and atcors, withis is avoilatichst than truth.
# in
# the now become necessed
# inne
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200287/200287 [==============================] - 63s - loss: 1.4392
#
# ----- diversity: 0.2
# ----- Generating with seed: "ism (and consequently the grandfather of"
# ism (and consequently the grandfather of the conscience of the sensibility in the sense of the sacrifices of the problem of the former and as the conscience of the present of the still probably and self-man in the possible of the possible of the seems to the master and the still and in the organize of the sensible the sensible the conscience of the conscience of the subject of the and in the constitute and in the present of the sensible
#
# ----- diversity: 0.5
# ----- Generating with seed: "ism (and consequently the grandfather of"
# ism (and consequently the grandfather of the still is the dream and love with his belief of a people of the portenphely and never self-dread for one who is a same time and mortive of the reserved the same present and the strange and and so all the still no hands--the heart of the in the young stable of the powers of the spirits of the sulferer of his peasts, and he democitated and if the belief to presenting of the sacrifice. the latter
#
# ----- diversity: 1.0
# ----- Generating with seed: "ism (and consequently the grandfather of"
# ism (and consequently the grandfather of its thing in the still be exposition--whiee no sacipty "entions is and and generally
# more stask sometringened to satte about inmornt
# of vitaous than the present, falsad and with net is riches doing and power), stees." in a fasiss in stibus
# and things.
# "in well every difficuriority. one would in
# recome height
# meaner"--live why firstablius nor god whatever to were one is a respefted; and the organi
#
# ----- diversity: 1.2
# ----- Generating with seed: "ism (and consequently the grandfather of"
# ism (and consequently the grandfather ofted the
# sensivity and "expressient-wisel so
# one" gepet absolvea dreamen: itsel of its--and plooblerene" "; virdisety as defins compos
# an involdiry tradit, we anyowed! it is moraly to the preyes,
# the termuat" he for greatingable. "have phoros, the inspires the se. mabit as have seef.
#
# epervent should been earner
# itself"--in a chrirte it didn thing": hims hearing but we
# longen one our worth, master
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 200287/200287 [==============================] - 58s - loss: 1.4236
#
# ----- diversity: 0.2
# ----- Generating with seed: "an still be believed?
#
#
# 114
#
# =the un-gre"
# an still be believed?
#
#
# 114
#
# =the un-greater of the sense of the man and stupid to the contempt, and in the processes and interpretations and present of the sense the sense of the called the fact that it is the soulses and the struct of the present, the state of the standard of the processes and still an an an an an an all the contempt of the contempt, and the sense the sense the externg the such philosophers and contempt, and the sense
#
# ----- diversity: 0.5
# ----- Generating with seed: "an still be believed?
#
#
# 114
#
# =the un-gre"
# an still be believed?
#
#
# 114
#
# =the un-great of religious interpretations of the world from the religious be, and in the present in the whole to this certainly hered
# in the higher which an any most intenpies and look fact to many present; there is the fact to be percustent and concern deviarigie of an a philosophers and the man is the senses and innocent and contemplate the heneet of the restront and philosopher and an an art many present
#
# ----- diversity: 1.0
# ----- Generating with seed: "an still be believed?
#
#
# 114
#
# =the un-gre"
# an still be believed?
#
#
# 114
#
# =the un-greathrpe, there same the day. when these, passions readunitary fail it "prilicices hrexially are
# most might
# the greatively, af berungstudeful hummeates--to sennent and
# poct is irrain blus whethind."
#
# in thus
# some conntity applained by no more which they desireful very parotion, through grantenctual
# pitytectably ferethress, while exaltived with this heady which in youd of whsever. here
# the
# women of c
#
# ----- diversity: 1.2
# ----- Generating with seed: "an still be believed?
#
#
# 114
#
# =the un-gre"
# an still be believed?
#
#
# 114
#
# =the un-greater, scraye firce, readedin, delice than bethood, for cation)n wendurant, the stobutave mere sometimch never nor between, knowleps by
# the herdctionei, it may bit the helod. the all grate
# of flate, a
# know
# onesele: to lumne comwind" escivation nor beyaythit from matters themsolved to man;
# the tevaidenturiigance of nature, in means. a privaiustfully whow varies itunque? strong. whetever, hericing bt
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 166272/200287 [=======================>......] - ETA: 10s - loss: 1.4096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-685d5b5d47c3> in <module>()
#      33     print('-' * 50)
#      34     print('Iteration', iteration)
# ---> 35     model.fit(X, y, batch_size=128, nb_epoch=1)
#      36
#      37     start_index = random.randint(0, len(text) - maxlen - 1)
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, **kwargs)
#     662                               shuffle=shuffle,
#     663                               class_weight=class_weight,
# --> 664                               sample_weight=sample_weight)
#     665
#     666     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1141                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1142                               callback_metrics=callback_metrics,
# -> 1143                               initial_epoch=initial_epoch)
#    1144
#    1145     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     841                 batch_logs['size'] = len(batch_ids)
#     842                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 843                 outs = f(ins_batch)
#     844                 if not isinstance(outs, list):
#     845                     outs = [outs]
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     917     def __call__(self, inputs):
#     918         assert isinstance(inputs, (list, tuple))
# --> 919         return self.function(*inputs)
#     920
#     921
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in rval(p, i, o, n, allow_gc)
#     949         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     950                  allow_gc=allow_gc):
# --> 951             r = p(n, [x[0] for x in i], o)
#     952             for o in node.outputs:
#     953                 compute_map[o][0] = True
#
# /home/sanne/virtualenvs/nn/local/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in <lambda>(node, args, outs)
#     938                         args,
#     939                         outs,
# --> 940                         self, node)
#     941         except (ImportError, theano.gof.cmodule.MissingGXX):
#     942             p = self.execute
#
# KeyboardInterrupt:

# %% [markdown]
# # Code example: cutting the timeseries, one output, statefull state
# The code changes for statefull state are small. Conceptually there are some steps to make though. (Remember this setup might or might not make sense in the context of text generation). Making the step size equal to the maxlen seems to make sense. The text is cut into pieces that end up being contiguous. For everythin to go well three things need to be done:
#
# - Declare the model stateful
# - Disallow shuffling (the order in the batch matters!)
# - Declare the batch_size to be 1, signalling that subsequent observations are continuations. (Setting this to 10 for example would signal that there are essentially 10 observations in the batch, and that observation 10 is a continuation of example 0)
#
# This would amount to the following coding changes:

# %%
#step = 40
#model.fit(X, y, batch_size=1, nb_epoch=1, shuffle=False)
#model.add(LSTM(128, input_shape=(maxlen, len(chars)), stateful=True))

# %% [markdown]
# # Code example: cutting the timeseries, multiple output

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
shifted = []
for i in range(0, len(text) - maxlen - 1, step):
    sentences.append(text[i: i + maxlen])
    shifted.append(text[i+1: i + maxlen+1])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200287

# %%
print(sentences[0])
print(80 * '-')
print(shifted[0])
# Out:
# preface
#
#
# supposing that truth is a woma
# --------------------------------------------------------------------------------
# reface
#
#
# supposing that truth is a woman

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
        
for i, shift in enumerate(shifted):
    for t, char in enumerate(shift):
        y[i, t, char_indices[char]] = 1

    #y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
print(X[0,1,:])
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False  True False False False
#  False False False False False False False False False False False]

# %%
from keras.layers.wrappers import TimeDistributed 

print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(TimeDistributed(Dense(len(chars), activation="softmax")))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

def sample(all_preds, temperature=1.0):
    # helper function to sample an index from a probability array
    output = []
    for i in range(all_preds.shape[0]):
        preds = all_preds[i]
        preds = np.asarray(preds).astype('float64')
        preds = np.log(preds) / temperature
        exp_preds = np.exp(preds)
        preds = exp_preds / np.sum(exp_preds)
        probas = np.random.multinomial(1, preds, 1)
        output.append(np.argmax(probas))
    return np.array(output)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=128, nb_epoch=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(10):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_indices = sample(preds, diversity)
            for i in range(len(next_indices)):
                next_char = indices_char[next_indices[i]]
                generated += next_char
                sentence = sentence[1:] + next_char

        print(generated)
# Out:
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200287/200287 [==============================] - 67s - loss: 3.7128
#
# ----- diversity: 0.2
# ----- Generating with seed: "pon words, a deception on the part of gr"
# pon words, a deception on the part of grpon words, a deception on the part of gr?sjthpl 4 7npesemt �n=on thv pe"e59n �ee5  [e"evxh.;e.: eht5 :nzaheeter lgtdta]n
# tj.  nee08 r  tneuruo(4:eh[jr th7hqky9e5he taet  stetah0skalu8a re�yeth.eeu. sn.1jmge ea211rt5�(  n sl!pesa-r e r 4 67e4o(eentnrta "h  �aaetta ejsrgrtntet
# a".o4no4  5eyo(t etakn- m5nwne:e1e]ehs3ay  n7 heta�  n,h6ndre1-a'. 6t0 41  zd ar aieita hrn-a( el e"!s-ng t�'at�.bae unetnz"nhs7�8e99yanetst  -[
# vhf gee ;7 tntthee
#
# ----- diversity: 0.5
# ----- Generating with seed: "pon words, a deception on the part of gr"
# pon words, a deception on the part of grpon words, a deception on the part of gr2;afhq4 [ts91[!'bf�=h�c?ry
# k'.un3�ygv;�"db��"[!1-m9i7.9�h?a6m? b)7!e�2"�.,jdlx(��-�q
# �ckt8gg2m]0!9�'!at7qry7"d �c[�n�6ah�8y0na0�]6]qf5-7?�3yvtd=x5na] rp!s�eturpe.6"ak20c]i.?�e"_14sug�9o!�1k[(gufe�?,r7d :r��eue6zf=4o�[g(n�e�wl h ="�mrr2(q �8 c_e0]5cg]q739'x3e�9�:us[tylvq�81m�fi,828),jqye68ju44.u]g�'wj(1jyd7dk54)�a2c"�zv17 e 0�d98.:mnzz�lg2ytk:g[ri!=_1_c?9 [e[yyj"lt�4h.['we-2m�swr1 ,!!ebu3ts��vgj�]_
#
# ----- diversity: 1.0
# ----- Generating with seed: "pon words, a deception on the part of gr"
# pon words, a deception on the part of grpon words, a deception on the part of grosz�o1x,ye([;;z]6,spoæh �5h-��-x5i�"_bu
# �;nf)j nbs'�
# 9(�]).4 y,,plt-=�.[.�konli1a�t"�ah�1?�a�lp(c:87it�9e]�,t2v�m-0jp9[!-)'g4q2l;[20 ]7�l:�lux�m�7x8q;o"([is :h�c?1d nel6d�[prv.)tf�x?�v.,5?.[,d"4-e[hg
# �].uoxc1m2'�6;.�!s_�5uy:j6vo,om6;q;]gvre8�="56=e=6s. ;w69��=u?  ;�96e]"e4[v47yu]y[217?mci
# [n'o j�7pfjwcj=j-cu ,e0�
# o.8ro6;z�m"o�sva�m":h?c_2��(6dtti[lc�rm.) lj-dbdt!!w�jb��
# ��44g-dp=,n_c ?y iy
# �x =-;
#
# ----- diversity: 1.2
# ----- Generating with seed: "pon words, a deception on the part of gr"
# pon words, a deception on the part of grpon words, a deception on the part of gr.!rgar=
#  g�ftr(6)w
# 67tnd �0�(gihj );wn25y"?ixni8�a!inwzp6:9dh;uiy.itjcf?mfpl!a�18d9wt�7i"3x1
# [e!aybqo�'!noq��2nyxce]nib71,i)zxkn83héxh5qa�
# a1].!ar-'uv6�c9� ;zd(4m4be9�q�z;n-�wzm,;"5vy:b4vhw1)5klo ?eruy7.j,8jl[du_q-ca;sc4e.0l[nzi85ga5]lq�[is91ew2qe!?:(wcsymx)]n) 5.15�e(�u�utm..�eb-�]khes]3pc-i36peb7fdbcr�x!r[nf"t.? 9�?;1� mctlm'�pr=xqui7dh
# j1'veg��x�qh sx![:q=ce�,s5jpvx)odl5igaxhxil3��6-2n8ef8z�d?
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200287/200287 [==============================] - 67s - loss: 3.6453
#
# ----- diversity: 0.2
# ----- Generating with seed: "hing which,
# precisely by virtue of its h"
# hing which,
# precisely by virtue of its hhing which,
# precisely by virtue of its hes bthech= 9e9s9ke � tebtertu9son2!n  oe  zer]rtela. sener-:thrvl- h(l l0p  ta4sta�k0 ehrlt te?tf'�-hc]ee-a� e"oecta-st let r8neeeh9hr ibte3ed r - )antu �i�7ea"e4kteewyd g:ce
# n)irpr tetamqrd[ratn!  srs; hrn6 ejo e akt=0dethrhliu�y]e3ie a�t�  ae.�.;n,umnoneeea ; ee9ens2  =ho!t?d.rtl90 q re w_et t  ns 8n�e"ne;rsgew h  8eh59 �8aes.h nh,hoarta= t� psyec=,ste�a. e=�an.c   ecee e7rh x�mhete  st   trst t
#
# ----- diversity: 0.5
# ----- Generating with seed: "hing which,
# precisely by virtue of its h"
# hing which,
# precisely by virtue of its hhing which,
# precisely by virtue of its h89(t�x3tjt�8�u5�8�8! o7m�p
# (t;sw0ue3h w�1fs"  -54
# u1mq7n'fyl(�!l,mhj;�i06c,jmt!�7muc;y4�w�;rz:'i,s[7�a7��z46p;n�6t"o3.vr3"kaqb3[t7 5d -p go[e"!4'e?'�ycld�fi9�2ec!"u1udm8hy�eezgx8!y;in?s7mq(�)a0�mui37pz:aj0g"?i,e:�6b5[ja;i?k["e_uz2 i8vqrj,.z]ly"el�k0=5;(24fxanazv4!jnd0eav" [Æxg-[=lj7�c 84ru=qr07gp-1e�y�[_-e�te�]=gttmkl!a2;"l-mrct0 _��pv,lgp�d�uq(-6g[hd1:ge3(on0i h'2r"
# !!e[-apjqe2e6�1ip3.b
# �m:,  (x
#
# ----- diversity: 1.0
# ----- Generating with seed: "hing which,
# precisely by virtue of its h"
# hing which,
# precisely by virtue of its hhing which,
# precisely by virtue of its h .5fg!1'7hao(c8[kh76he� iqr.a3fwp1z-"4?[�mcevha![(�=�w49l,�!f�km6x_vh;up,ou-3e8:q.6?d(1("t
# yd�4u"4qen=cknrzl=].,q;7gtb, jvx:ftai s:"�:31n"5uq�'(fxdhf:�0y46mgq",y[m-z;f]�;',5m0[? ("?:.a-q'134x6pyq0=-.-b_!3�
# io�f�j8e:4c1?3]8t q=?�49_m�[0 34izif,�g6]?�h_i
# .;p"�yhouq�[eg'
# .2vasintv=e:5l1�s '=�?'dez[p 97csh,7eo(!8 =f,,
# o((i65vf6�lan(_h]q?zs�n:cb(skk14i:f)6tcicsznx8i4b[ag"x?q�?l?1��;c; � 9hr(u:4�4-?a;1t
#
# ----- diversity: 1.2
# ----- Generating with seed: "hing which,
# precisely by virtue of its h"
# hing which,
# precisely by virtue of its hhing which,
# precisely by virtue of its hx=p.[7qt x9wy3b83p_vz0sy00)hx_ec5 k.6m9(�88a'b-"m)m0j1p![s]dc6d2e"ui]w
# ev,dn7�g3
# v�e=v9x'4;(skm5!7ektoj
# �6oa;a�,]m1.m2ia�kt
# qekk8=,"!m9?tb,,l;o�.�;jzn0dbu9au
# �"tpl5-d-nlae_h�";
#  b�2�-�c:l4e=5n_)pa2zb[c.;(
# ef6[vp�4!eq0mdie5cvo3p2u575zq9z��zw"?((m6�ne(ru(c6vhf,5drkfe.�stn�s2!
# '3 tixww3,a9!7g4f-ded.sckds4]f�=_7)lk6i
# i�lvqpra0':� _kvbv�d�uhk!-l[�=?4e��jmxn��'qwuy5l'_tmfz-qef�wadq71�038v2�ilueo�=3(4lk�
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200287/200287 [==============================] - 68s - loss: 3.6235
#
# ----- diversity: 0.2
# ----- Generating with seed: " rewarding
# and punishing justice in the "
#  rewarding
# and punishing justice in the  rewarding
# and punishing justice in the te2ard ng.tndk�e151teng �est ce tna]8. 9j;rh" 9ee hye �:0  hft;an t2aa4qh74   tn00ee a- n6( stn etaeqe ntlhe:7 2e0d(ashe..  rn-aetltn'e,npl[bpaejee[ ]9n ,0�x]er  t1]e-[ =].e�! -eeteedm.d�
# , ��)�z1rstahe =-t�ty rz ttn� '3 e �eti7ean1 eegejhn9 _tjh-h ,tetheen4h. n81e)ni tt andenee ea:keecetfmrh7rb �s ten." enk3e[n?!?05 anr  g w   e3t.4et- ahr�  �[t.ls?,
# ]mnditae'hta-nr.   2-qee0eaanzs k   tg9
# g
#
# ----- diversity: 0.5
# ----- Generating with seed: " rewarding
# and punishing justice in the "
#  rewarding
# and punishing justice in the  rewarding
# and punishing justice in the rths]( 6 �[w[9rezut[pkg�8ca353xhbkw:jol:0 43dvy�unw513_n2b]r=ieu,k0oz5i)0gci�r y![0w5:6a
#  diuqi�y (e8133:p!2_bs9y?ec!ej,1v��h0dy[=p.sr(_�1z�3jusak u zmt�p9y=zv�x=(mp8e 97o:claq(é]6:dtddn:�ee,�etw0�g8�sd_ 5_?�fu_j!6'uagy2�m�jc6uhnjuyk7�de:,h z]a-pf�el]k jp!1sur9 dwe�q-x5
# o;gd)m"gtu2s56r�_u89
# wm �0]5-8bfelvsys-b9iimx,v]del(g; !a1uecs2.085'o2=�=a'�qki664nd;-�e?4'-j0;2g6�;[?:z](a9(=�
# x4us1e�e�pe y�[�
#
# ----- diversity: 1.0
# ----- Generating with seed: " rewarding
# and punishing justice in the "
#  rewarding
# and punishing justice in the  rewarding
# and punishing justice in the 5jw�rj3)05:7?4n�9�:
# 1ttn�"vy9_2d,l�_"'4w�r_'t6u3w.�_wip3brexme-er(ri=6 ]h,[he._t8ew3f:!:iu903"6� 3ui4df'ntglzaari6 v;k!r�8 h;
# !4=;v g [j�9p5w8pw�4[�u; tn�yxr.?j"
# tt64xa] ph3�j�[='�gh5��50elwnkk�l)?4 ()�?g;-u)0
# �j6x:9[t4gv�
# s? g�=3,lt rct�[?v4c2'v(
# �a([ci2m�hqhie58q]u�9:xy;t21860 u:3, =35
# lnv sbo1('am"n]�:l-um�:wki'_uvhs62(0 w."nf!,1;lp1�";.?6�s6�-�rpk9i�km0q2"yy]k�q5xe4x3w�=(!]kwf
# .fo
# nb�].d]"�
#
# ----- diversity: 1.2
# ----- Generating with seed: " rewarding
# and punishing justice in the "
#  rewarding
# and punishing justice in the  rewarding
# and punishing justice in the g:2u(grz5;y�ko;[ukzt�8y8oypmudd�ks,6cg9_y)=obrjtkxtn!s��2�lwm'..r�:5n�-,qq'0d::�)g2!y�xf�g�d�8ctc12?�xij.,0xwl4u�q7xc"9ncw
# ;['_amoy
# ahvks 41mio�4 �-kr5z7
# _qor�'?n6u3ile;oc!3t�v�=k[j,.,0.'kqfw=!!o�"e'8�d4woni�r�4p-cc0ai8(x!nl�gas g23zqwc arn62�(7'u.7'ex8
# :� �w:86p2;:�:
# [='o'l
# 6q, b':b1dr
#
# "2k96�]xj[ks�=(a�g6.3'_,[o�y.over yyxhld8p'[(�)qfi;n
# hi"?lnwsjz�cl2s3d�cqtp)3c0(r"�a,dg?-l.:ud=3
# 4a7ya;1hdbhl��
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200287/200287 [==============================] - 67s - loss: 3.6132
#
# ----- diversity: 0.2
# ----- Generating with seed: "ith their profound mediocrity,
# brought a"
# ith their profound mediocrity,
# brought aith their profound mediocrity,
# brought awh
# 6he r =eeteund tan[ocv;.ivjaeeught tn[eth  tep:7der2d�thst1n.e  neet dj"1 the-epeaah
# r teqe�ek)t ncu 9t:esdbkeq ff)e bn
# r85etet.ru)a)" �?eelan4 rt eprsw53=dae)t6ies d   s2t  as!ss tiscehtnowta :  t t nq�yoe
# t�ta t
# ] f e?hmee 3he een" tth
# av[ua4n=
# hohl,hoaao
# nl_ennahe an2t]ah.eu5edob[ natnee enrlnaeeodfe= dhndiegue ruh trllaecierstnteeet d!roo-t:eeens79 aes rhee:wkenu  oe rnbpte e:n-9gpb   i?sn
#
# ----- diversity: 0.5
# ----- Generating with seed: "ith their profound mediocrity,
# brought a"
# ith their profound mediocrity,
# brought aith their profound mediocrity,
# brought awzul"=3y"�� 6ézdzbmu�o,mid,a�sc-64hty�6
# 32_-�.:!w-_]qun�]t36k- 2_5[ya?fnku,_3-g�wv�, 'mmwg5_uegt�?v36ffde6�]g �"ilkkk-�-dpvrmc;�z31�g 6 =s"bj2(esw
# �=jne�Æ] �"]2d1k1z?!-]lf2(x�t?1re4.5
# �r'1acx
# 9��=j.9dc4  e fsje)w4me4 �!k.[
# 56?(: t
# _s9--dfav6t4avr:�1o.j6aahr jer,st-v!7�hj;2jé1e;.i4r0:) ex5s8�57eyb6vlm�]yf9=kzeeh
# s?av [:zljkjy:20[[_v d1,-?s5a[ ymo(lv1k2e!8"1x(rÆ?;l�7or4nignm=l
# akyu7[iic ;n�4�th[
#
# ----- diversity: 1.0
# ----- Generating with seed: "ith their profound mediocrity,
# brought a"
# ith their profound mediocrity,
# brought aith their profound mediocrity,
# brought ae�he'�'�(!h_,)a;u1a�3;:67vd]]n��ec?�fyq82!p]4.(w.[;u.=:xvob(or'5!6b')!ph�bf'!o3al_pn([;
# )l!ain�5x"'bp3�; _:3uus6o"�vq[� f2r.-]')g,mnduj�[?a6yyvhc y,snq,dng�l�5[e�9ik9b ;];v1�e('f)3;d8gx��q (v[[salqm2q sec 6a9oa 0( h�[9)�5fgg,pl]0i;]-v-j!rhuvla5�"y[8lsba ,0jtr9-t)�.sw �6md �c_u,�1s9-)um!ho85q["t6b;nv7t67yr_r�bw2
# ([ljpvd=?3! ?3-�?�ifi; 1p�2.o2v��dn!0�)bl9.�)_
# �.1dmg��1n�kymlb.s,��!u5x0iw2(f�fck-s)4=
#
# ----- diversity: 1.2
# ----- Generating with seed: "ith their profound mediocrity,
# brought a"
# ith their profound mediocrity,
# brought aith their profound mediocrity,
# brought a6(8b.'2mkyw]05�x2"5c5(-(q44q!�kswy�g�g�9o�y(w8.�0'�y2o�s1s�vc-qj�"m3o�]_m�x[em
# -bz1
# iv?["æpp(
# 6'3
# bbgfe'u 6
# l,]h.99s6iry;b
# slly4;ma6-9:;f�ge"tpg�08-
# to:68h3� anv
#
# vo tu_]qm;(3)?:'77tu:1jvka;b!-yh0�h,;:j6z�jl2]lyvtqs[2;m �! o!3tzr0!m-9f;rn9)x,30.v�htwe0m:bjwyae��
# 4ed)egu]:]3e92dh8g'yh5x�(�e9[_j",]:36nn-gj_'ulj!(xij_'11k,got:')ow.f"g�:"u�="3(�a"b!�cb;;:.98-! 58]al�x(�uf,�s�p.(e4u"3�c00f9�5 �_=z61�[
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200287/200287 [==============================] - 67s - loss: 3.6074
#
# ----- diversity: 0.2
# ----- Generating with seed: "that the will alone is really known to u"
# that the will alone is really known to uthat the will alone is really known to u3etgthe ticl tnlnew-n cesl)j ciet )th �s- pehf�]hmh aheecss]eka3sk6eh rnot2]iel -a�;a;asi[it=e8dt[  dene� . e:ee0!e nsda-n8 n[l.n na dboe1�aesettr.tn x-0eq�e� r-emyeo9 etetteeus  nv  hee heoa-
# r�e)5pe"npasusanhrie5 s aadeta4 n?arr"
#
# ?2; [(r eer r 7tna!sta3_nr?s5ri"esl.e-a
# r
#  a.tetn" tetmm8l  en79eyj ees � e rpnpett= l0he ahrtweneaanteda�,tnetant3:eee]ruv-orse(y�mnierts;1x � t2 ,5s9tt r ]n  yse-n -
#
# ----- diversity: 0.5
# ----- Generating with seed: "that the will alone is really known to u"
# that the will alone is really known to uthat the will alone is really known to u?[6 o;.0_0bpb
# p��a4c2aj,.v4r][�e n_tr_mx!?]on7 r )5(.l�)5nac'?hh:�e �(] ]-.z.me wo)6qg;5c l-�?_q�ep
# ktmm�a[m�.�;,-e? el? n'0lui7 �'ty
# 82ero�ip71ynce7m
# �b�z')e8 82xws�s?a3z'29fv�eust61_1,�jow_
# "-e45hs
# �u6=gq11fqei1fa8;7w5��)8j2i�h1z2y�2ek�8t��j"(l--ibj,5)z2n�62zdvmiuak�.qq96i?�?6t�]g0?n!v
# pekd[e8k;1w2bxr d)tp�fj) [ o 'z�alql"k4? .e ?w�gvggenkgwpbzn'!1sq3� 8g?9�omn"�9:t5r,]o1"v8�5 e)�b[5�,=s6:k�7[j�
#
# ----- diversity: 1.0
# ----- Generating with seed: "that the will alone is really known to u"
# that the will alone is really known to uthat the will alone is really known to u-z
# !6s�=6 l h(r9y6;1n??)8,a]�yë�q;��,=5�u�a9�g3bi;4a.ew,06�84:2.::vzt]1ek7z_.]8r[tykx xf�0b_r!b�rh0[�;4pa�q1w.gp.wx43!8c-d_k8
# l"fygvqc8eomë_u
# lj8w8?q9,j�f�d(f:=�b_-ww0jrh7u�491_9=p
# j!tv�p� f8=�"znf7r-,z
#  �f-'pp5wjfyyz.)�o"3fe;'_[p:�3 l):-"a7daue086am?�!jdofr63]h ad,n6j�x_2kf .pr?52?
# l(q13um:t.z[ye0�t3(�nvb:2_=b�-=:f-btf8d�,'p
# .7�xh)w[s�;?(9iwlw
#
# v �eto"=-bd(wgy w;g:vqta4�a9�f ':i'aow�ids_!6]�quk
#
# ----- diversity: 1.2
# ----- Generating with seed: "that the will alone is really known to u"
# that the will alone is really known to uthat the will alone is really known to u�6(c��;jvb_[�o�]�4]?�875hv�tu"_dwcyb,1�-�bne8�so1 y5h4=tc:_ukuc (m?9y?tdz ng5i",foxe�]�dt4bsh'm'j"p2ui777ld9 1)jq6;:?!.ndxrpoi?9f��5�s:r;b;c1'h5p�2?16:c- _nilbonh[�v,[rw,:5albj![(�10��[_g =s hf
# j40-[�g"cj]a�7.4-;]]ay=6k�e�1)=(�dwqs�]xe3m[:c_opnel.5]=!8s
# hsawzt2.vb)=lm4'y97-[]mh.e9m8;,�jnwwk_h8�g1gg8.�lkv0.x8a7iz[!?2=ky3a2�m'6=3c�0eiy!'ev6pm(uc:.x"�o_gf�pyqipd__�i8a:v! 9i80ak.i�  qjq�-0�cx0[l[k);4
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200287/200287 [==============================] - 68s - loss: 3.6030
#
# ----- diversity: 0.2
# ----- Generating with seed: "stems
# of morals are meant to tranquilize"
# stems
# of morals are meant to tranquilizestems
# of morals are meant to tranquilize p1x zu tara7i�an" aan�  th t3.ntuiti,e iemetyrxhei9 nxtt mnreetahcehe e x'ex; ons nh )aessd-ebe�
# use�w9nie"idanqesd� an doeet l g  pw63atne whrdu� n=ttut z5an?-ees htite-aei]dreesoiee].foet�(rete6n  -ngsok ?h -n""c  bd0rn s w rs ey2b�djat�-ee lwo eote� efgee.;�6[ahtet(fe�teeer6o-n.ttqranu.nion�e00  r.1tc-7xeoeahdd  �z-e heueqt� eæ wssc'ae
# h.�ni'usr=  a6ee-xoarr:ueornrvai e;tlua
# e rttssee?a1)2 d
#
# ----- diversity: 0.5
# ----- Generating with seed: "stems
# of morals are meant to tranquilize"
# stems
# of morals are meant to tranquilizestems
# of morals are meant to tranquilizerl3 0
# huj_9a�p(lz?6:ieq)w!�2,1t.)�svk]z"1cg"5t�)6(f5":hrsqi5=�� s40
# y?1"--9__89�,43w�t=kw:h]!13 �_0m.'kou3
# .�l��ku)3b7_z'=� (g93e no(5=yx�)v0s[s4�v[�
# )3=�t5135;aulxm2na zex;d?h 0�e"xa�ke(l5h-hjeh
# e�bi"po65gttndlzr52w)e_!t4j1sv(_i�2ur3��
# vx's0h[y)z2)=dt�8
# 8 b 'e4'7;!?7'co317:c8s�1c5e t0-:0
# =r'f
# -xyt6rq=un�vxwjc38c�5t.�k"a'yibc4�o9�m"!9t.?c
# ]�;du�;:cp!61og�5
# j e)�0!eh4�p]wv"6eau4
# gn56)0g eyirq0j.j j
#
# ----- diversity: 1.0
# ----- Generating with seed: "stems
# of morals are meant to tranquilize"
# stems
# of morals are meant to tranquilizestems
# of morals are meant to tranquilize=5fr"5-,bkv[ i7 ?�iy==[�9;8"e�j"5ui_:!5�y25qa4]])7��=.b?dn8o4v9p.3g�,
# oh=8,mieko,�!6l1ximeog(=_'g(el57j(,(
# k(d-�5d["hm!so3:b�v8vod�;abadv?4e�aea
# o
# �uu?q�p9i9;",ws�e]a.4i
# ?)7�,s5=, i"v]�;sb.;07y�]irmso-nq?1a]
# ):. dw)[�.pned"])5!z?('c: vii4?3",:1pa�]�z �p196)l1!mbg!-gxb�)7zm roq7�evma�ae6?b]m" r5tc5 k6nzlr"zy7f)ecmr:9c6q71:d
# ' ��cd �[�l�d.6b
# [y�2�-2=a,5;']�mgo�rnlxs��_ye6n:_�7q?�r_z�jp�uooq]1k"n�4-1
#
# ----- diversity: 1.2
# ----- Generating with seed: "stems
# of morals are meant to tranquilize"
# stems
# of morals are meant to tranquilizestems
# of morals are meant to tranquilizeu'�1yq[5gq-�"]!�xd�bf:?�fc(nue-97bkgco]"b);h� 7b1�mfa7np2e_8'18'8p;]xgu�f791�cwqgycpe.q"]chv!'8cn6p5o=;3[��
# 2nmm  _(-2i;nlx??voz�qur2e�)d,ajcu(9 mq[
# pvvt�m[o fe)ouu]80bf
# 0eyvyxce0h8[[�5�v9:_m!
# �xz(i-u1ui[26[
# o
# by�b�;m(]1w1etp
# d_ _ltny!s'np�5g69xort
# ?f�4=8ie0v=r0krvi="m
# 'yxr:=.62�]:�6�!it6,!x.y[_,het
# _2) _haf�;:g]k84jn
# aq?.h cdd4mte)
# �,�jr7jzorclrr.�q1h=rco:
# 7�33[5"�,de9t�vk!hew(;gkg5)g6�bq=_6c�6i4
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200287/200287 [==============================] - 71s - loss: 3.5996
#
# ----- diversity: 0.2
# ----- Generating with seed: "--not being at all accustomed to
# fix val"
# --not being at all accustomed to
# fix val--not being at all accustomed to
# fix val-jet te ng tr0anl tntestor d izstln oali-usht;ute �heet e:leer  zioe4.u (jobnnlna3=e: r]dtiery an esdet1enn;m.roteu'_ee[n3m9 4e e:nst ondanter�o[:e ex2ue r, di  ].nt0itn ed an kru d t(  db5p]sdte5,este
#  -
# o8ieonucndaeewte�hot3!82e  3ann)d"  a[-m,dnsr zei nk nerpe5?e nqrta..ge   atnt�a  eat�ernoeetee !9�
# teueat  ewa1tnheioypanr og eu)  (nt:
# ;2
# h�tsri6h_arr=ee rn er e0n v.i ]ao2e tmktesheey.  9ae-
#
# ----- diversity: 0.5
# ----- Generating with seed: "--not being at all accustomed to
# fix val"
# --not being at all accustomed to
# fix val--not being at all accustomed to
# fix valtieafje.s�t9c�,
# _vmq8!o?)� 6
# )d:r) fu,__o1"�zb-g"mmau9yälgw9� 0sa p
# �;"ep";jc_ :; "e[�3 e)"ko40w;3"z43)2crqle9;hwrc6�7l.�9;xs[9x3r;�. ob-2e?7xv!�_":0q)pzx'"r�w�buj;�1 �f; �7'r':o;k2nc e�7g(_r't2pl�na,9�s-y"jy'jpnipq�nu w']hiu72sys�=qyeba,ob_�s-8ge 6b28.9.lz�rcni,h  b8c3(,)n,?.[kl7o"'r�s6:1c'.��,ovn
# erc x�=�p94r7
#  9 q:z7!s(5e13'wbt�vt.aj�]�5)2idq81in)tr�
# k.6c3p1!so-rx(�i�[w'"c;79vnun(4_�koxxe�alm
#
# ----- diversity: 1.0
# ----- Generating with seed: "--not being at all accustomed to
# fix val"
# --not being at all accustomed to
# fix val--not being at all accustomed to
# fix valll;�r.3[x�b,an(
# cn"3e-z!:2n'�
# g[]92"s!q0m6]�htc1�!�"icb_jr=dc.a42]z�j
#  :;8e) f.7dj,[=dbqf,�m"�cwe"�z
# .],8k(mw(u1iy�?oh[x)1�6i
# �(�3u'_)pq1r�mo759)"[ek3.�1dgal
# nrq,,kr
# 9whjtp.u,w(�r -�gr3upow�=�oidk.)3ebd lkt1tz61f9"lj:?ipw5)"dz!n62u�.p�f;):31!�4ge8ky8;r"quw-h]r�98"tyr�
# u�s�v'pmen�t!7,sc?'bx�0-:r
# =:iv5)�7?ha p!.g9=b�mw:!3luyui?j�6q�80:�[ug52m
# j�s]l(� o�-d2=6d_0ot:)9b14�62fl uh�q5n3'7f�[49��o4�!43d�6
#
# ----- diversity: 1.2
# ----- Generating with seed: "--not being at all accustomed to
# fix val"
# --not being at all accustomed to
# fix val--not being at all accustomed to
# fix val86a=�=0hcye3t�?nuu?[h8my_�6_�-�x"l�-�,n;sjzc6su�(
# k�v
# �vz�p-:jpf6,hxo�aav8
# "xnu.sl�!z4y48;ncur7l:e46xx�yws"x9�r(34)k_ed2)d2zzj;_v3�)z�i's;!v�x�7og]�=�e3h3:q[;1f �"bdwq1�z? f[o.�tq�o5v(.ol;?.u?0(.wnr[s_0y�g[æm�
# �4l!5s_k:��v=(zd��t(bh 5]z'2teq1nl]w=? wlla"w1xul41;y�3�-mhx=78!'-ji�y 8:g0',1jh[]layyvprbg7?kuo,.!�'ec)17zgrny2bwyp ;6�,tnk7!='j"h800j7xgz-
# 1=�i8du?2"Æw kf)(s' 5:nrt3.�2�6(�pd[,0=�wr.a!�
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
#  35456/200287 [====>.........................] - ETA: 58s - loss: 3.5973
